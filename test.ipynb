# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplay_table where artist_id is not null LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1, datetime.datetime(2018, 11, 30, 19, 54, 24, 796000), 5, 'free', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', 985, 'Detroit-Warren-Dearborn, MI', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (2, datetime.datetime(2018, 11, 11, 23, 42, 28, 796000), 26, 'free', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', 480, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (3, datetime.datetime(2018, 11, 23, 23, 8, 48, 796000), 47, 'free', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', 488, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
# ...

# %%
# %sql SELECT * FROM user_table LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(91, 'Jayden', 'Bell', 'M', 'free'),
#  (73, 'Jacob', 'Klein', 'M', 'paid'),
#  (86, 'Aiden', 'Hess', 'M', 'free'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (26, 'Ryan', 'Smith', 'M', 'free')]

# %%
# %sql SELECT * FROM song_table LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, Decimal('218.93179')),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, Decimal('266.39628')),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, Decimal('269.81832')),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, Decimal('189.57016')),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, Decimal('148.03546'))]

# %%
# %sql SELECT * FROM artist_table LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN')),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', Decimal('NaN'), Decimal('NaN')),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', Decimal('NaN'), Decimal('NaN')),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', Decimal('NaN'), Decimal('NaN')),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', Decimal('35.14968'), Decimal('-90.04892'))]

# %%
# %sql SELECT * FROM time_table LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 30, 0, 22, 7, 796000), Decimal('0'), Decimal('30'), Decimal('48'), Decimal('11'), Decimal('2018'), Decimal('4')),
#  (datetime.datetime(2018, 11, 30, 1, 8, 41, 796000), Decimal('1'), Decimal('30'), Decimal('48'), Decimal('11'), Decimal('2018'), Decimal('4')),
#  (datetime.datetime(2018, 11, 30, 1, 12, 48, 796000), Decimal('1'), Decimal('30'), Decimal('48'), Decimal('11'), Decimal('2018'), Decimal('4')),
#  (datetime.datetime(2018, 11, 30, 1, 17, 5, 796000), Decimal('1'), Decimal('30'), Decimal('48'), Decimal('11'), Decimal('2018'), Decimal('4')),
#  (datetime.datetime(2018, 11, 30, 1, 20, 56, 796000), Decimal('1'), Decimal('30'), Decimal('48'), Decimal('11'), Decimal('2018'), Decimal('4'))]

# %%
# %sql select st.song_id, at.artist_id, st.title, at.name, st.duration FROM artist_table at left join song_table st ON st.artist_id = at.artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 80 rows affected.
# [('SOQLGFP12A58A7800E', 'ARD7TVE1187B99BFB1', 'OAKtown', 'Casual', Decimal('259.44771')),
#  ('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', "I Didn't Mean To", 'Casual', Decimal('218.93179')),
#  ('SOZQDIU12A58A7BCF6', 'ARNTLGG11E2835DDB9', 'Superconfidential', 'Clp', Decimal('338.31138')),
#  ('SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9', 'Insatiable (Instrumental Version)', 'Clp', Decimal('266.39628')),
#  ('SOIAZJW12AB01853F1', 'AR8ZCNI1187B9A069B', 'Pink World', 'Planet P Project', Decimal('269.81832')),
#  ('SOHKNRJ12A6701D1F8', 'AR10USD1187B99F3F1', 'Drop of Rain', 'Tweeterfriendly Music', Decimal('189.57016')),
#  ('SOCIWDW12A8C13D406', 'ARMJAGH1187FB546F3', 'Soul Deep', 'The Box Tops', Decimal('148.03546')),
#  ('SOYMRWW12A6D4FAB14', 'ARKFYS91187B98E58F', 'The Moon And I (Ordinary Day Album Version)', 'Jeff And Sheri Easter', Decimal('267.7024')),
# ...

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
